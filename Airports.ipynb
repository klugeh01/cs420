# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sbn
sbn.set()
from matplotlib.colors import ListedColormap
from sklearn import neighbors
import pandas as pd
from mpl_toolkits.basemap import Basemap
# Out:
# /usr/local/lib/python3.4/dist-packages/matplotlib/__init__.py:872: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
airports = pd.DataFrame.from_csv('Airports.csv', sep = ',', index_col=None, encoding = "ISO-8859-1", header=None)
airlines = pd.DataFrame.from_csv('Airlines.csv', sep = ',', index_col=None, encoding = "ISO-8859-1", header=None)
routes = pd.DataFrame.from_csv('Routes.csv', sep = ',', index_col=None, encoding = "ISO-8859-1", header=None)

airports.fillna(0)
airlines.fillna(0)
routes.fillna(0)

airports.head()
# Out:
#    0                           1             2                 3    4     5   \
# 0   1                      Goroka        Goroka  Papua New Guinea  GKA  AYGA
# 1   2                      Madang        Madang  Papua New Guinea  MAG  AYMD
# 2   3                 Mount Hagen   Mount Hagen  Papua New Guinea  HGU  AYMH
# 3   4                      Nadzab        Nadzab  Papua New Guinea  LAE  AYNZ
# 4   5  Port Moresby Jacksons Intl  Port Moresby  Papua New Guinea  POM  AYPY
#
#          6           7     8   9  10                    11
# 0 -6.081689  145.391881  5282  10  U  Pacific/Port_Moresby
# 1 -5.207083  145.788700    20  10  U  Pacific/Port_Moresby
# 2 -5.826789  144.295861  5388  10  U  Pacific/Port_Moresby
# 3 -6.569828  146.726242   239  10  U  Pacific/Port_Moresby
# 4 -9.443383  147.220050   146  10  U  Pacific/Port_Moresby

# %%
routes_direct = (routes[routes[7] == 0])
#routes_direct.sort()

# %%
usa = (airports[airports[3] == 'United States'])
lat = usa[6].values
lon = usa[7].values

canada = (airports[airports[3] == 'Canada'])
lat2 = canada[6].values
lon2 = canada[7].values

mexico = (airports[airports[3] == 'Mexico'])
lat3 = mexico[6].values
lon3 = mexico[7].values

australia = (airports[airports[3] == 'Australia'])
lat4 = australia[6].values
lon4 = australia[7].values

germany = (airports[airports[3] == 'Germany'])
lat5 = germany[6].values
lon5 = germany[7].values

brazil = (airports[airports[3] == 'Brazil'])
lat6 = brazil[6].values
lon6 = brazil[7].values

india = (airports[airports[3] == 'India'])
lat7 = india[6].values
lon7 = india[7].values

russia = (airports[airports[3] == 'Russia'])
lat8 = (russia[6].values)
lon8 = (russia[7].values)

# %%
lat = airports[6].values
lon = airports[7].values

# %%
fig,ax = plt.subplots(figsize=(14,10))
m = Basemap(projection='cyl', resolution='l',
            llcrnrlon=-180, urcrnrlon=180,
            llcrnrlat=-90, urcrnrlat=90,
            lat_1=30, lat_2=45, lon_0=-95,
            area_thresh=10000)

m.fillcontinents(color='white',lake_color='blue')
m.drawstates(color='lightgray')
m.drawcoastlines(color='lightgray')
m.drawcountries(color='lightgray')

m.scatter(lon,lat, latlon=False, marker='.', alpha=0.2, zorder=2)
#m.scatter(lon2,lat2, latlon=True, marker='.', alpha=0.5, zorder=2)
#m.scatter(lon3,lat3, latlon=True, marker='.', alpha=0.5, zorder=2)
#m.scatter(lon4,lat4, latlon=True, marker='.', alpha=0.5, zorder=2)
#m.scatter(lon5,lat5, latlon=True, marker='.', alpha=0.5, zorder=2)
#m.scatter(lon6,lat6, latlon=False, marker='.', alpha=0.5, zorder=2)
#m.scatter(lon7,lat7, latlon=False, marker='.', alpha=0.5, zorder=2)
#m.scatter(lon8,lat8, latlon=False, marker='.', alpha=0.5, zorder=2)

# %%
from matplotlib.colors import ListedColormap
from sklearn import neighbors, datasets
